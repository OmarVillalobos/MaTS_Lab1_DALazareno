# %% [markdown]
# <center> <img src="http://oci02.img.iteso.mx/identidad_de_instancia_2018/ITESO/Logos%20ITESO/Logo-ITESO-Principal.jpg" align="center" width="960" height="480"/> </center>

# %% [markdown]
# <center><font color=#555555><font size=6> MAF1731 - Microstructure and Trading Systems </font> <br> <br>
#
# <center><font color=#555555><font size=5> B.Eng Financial Engineering </font> <br> <br> <br> <br>
#
# <center><font color=#555555><font size=6> I.F. Diego Alberto López Lazareno </font> <br> <br>
#
# <center> <font color= #555555> <font size = 4> Feb 2022 </a> | <font color= #555555> <font size = 4> Repository: <a href='https://github.com/diegolazareno/MaTS_Lab1_DALazareno'>Link</a></font>

# %% [markdown]
# <hr style="border:0.02in solid gray"> </hr>

# %% [markdown]
# <center> <font color= #555555> <font size = 6> Lab 1 </font> <br> <br> <font color= #555555> <font size = 5> Some interesting title for your work  </font>

# %% [markdown]
# <hr style="border:0.02in solid gray"> </hr>

# %% [markdown]
# <br>

# %% [markdown]
# <font color= #555555> <font size = 4> Abstract </font>

# %% [markdown]
# <font color= #6B6B6B> <font size = 3>  Include here a description of the whole work, use no more than 400 words, you can use **Bold** and *Italic* highlights, also you can inclue [links](www.iteso.mx). Usually is a good strategy to generate this text at the very end of the process, since you have to include all aspects of the work, from a brief introduction, to problem definitions and methods used, to finally the results found. </font>

# %% [markdown]
# <br>

# %% [markdown]
# # <font color= #6B6B6B> <font size = 6> 1. Introduction </font>

# %% [markdown]
# <hr style="border:0.02in solid gray"> </hr>

# %% [markdown]
# This is an introduction, normally, it is done at the very end, when all the other content in the notebook is completed but just before the abstract (which is short version of the introduction) ...

# %% [markdown]
# <br>

# %% [markdown]
# # <font color= #6B6B6B> 2. Install/Load Packages and Depedencies </font>

# %% [markdown]
# <hr style="border:0.02in solid gray"> </hr>

# %% [markdown]
# <br>

# %% [markdown]
# ## <font color= #6B6B6B> 2.1 Python Packages </font> <font color= #555555>

# %% [markdown]
# In order to run this notebook, it is necessary to have installed and/or have the _requirements.txt_ file with the following:

# %% [markdown]
# - pandas>=1.1.1
# - numpy>=1.19.1
# - jupyter>=1.0.0
# - _Add any other here_

# %% [markdown]
# ## <font color= #6B6B6B> 2.2 Files Dependencies </font> <font color= #555555>

# %% [markdown]
# The following are the file dependencies that are needed to run this notebook:

# %% [markdown]
# - files/precios.csv : Precios históricos
# - files/datos.txt : Otros datos históricos

# %% [markdown]
# ## <font color= #6E6E6E> 2.3 Install Packages</font>

# %%
# %%capture

# Install all the pip packages in the requirements.txt
import sys
# !{sys.executable} -m pip install -r requirements.txt

# %% [markdown]
# ## <font color= #6E6E6E> 2.4 Required Libraries </font>

# %%
# Settings
import warnings
warnings.filterwarnings("ignore")

# Libraries
import main

# %% [markdown]
# # <font color= #6B6B6B> 3. Passive Investment Strategy </font>

# %% [markdown]
# <hr style="border:0.02in solid gray"> </hr>

# %%
capital, commission = 1000000, 0.00125
results = main.passiveInvestingStrategy([("2018-01-31", "2020-01-31"), ("2020-02-28", "2021-02-26"),
                                         ("2021-03-31", "2022-02-01")], capital, commission)
# Out:
# 1 Failed download:
# - MEXCHEM.MX: No data found, symbol may be delisted
#
# 1 Failed download:
# - GFREGIOO.MX: No data found for this date range, symbol may be delisted

# %% [markdown]
# ## <font color= #6B6B6B> 3.1 Passive Investment Strategy: Pre-Pandemic (31-01-2018 to 31-01-2020) </font>

# %%
results["2018-01-31"]["portfolioInfo"]
# Out:
#             Capital allocation  Cost per share (commission included)  \
# AMXL                 133100.00                                 15.66
# FEMSAUBD             126900.00                                168.26
# GFNORTEO              95100.00                                104.91
# WALMEX                76000.00                                 43.30
# GMEXICOB              75400.00                                 52.65
# CEMEXCPO              74400.00                                 15.11
# TLEVISACPO            62100.00                                 75.45
# ALFAA                 26800.00                                 23.22
# GAPB                  25100.00                                161.62
# ASURB                 24400.00                                344.54
# BIMBOA                24200.00                                 42.89
# AC                    17700.00                                117.84
# GFINBURO              17500.00                                 31.31
# ...

# %%
results["2018-01-31"]["portfolioPerformance"]
# Out:
#             Portfolio value  Return  Cumulative return
# Date
# 2018-01-31        967640.95    0.00               0.00
# 2018-02-28        911720.48   -0.06              -0.06
# 2018-03-28        885024.51   -0.03              -0.09
# 2018-04-30        929790.07    0.05              -0.04
# 2018-05-31        860969.17   -0.07              -0.11
# 2018-06-29        926750.97    0.08              -0.04
# 2018-07-31        965529.45    0.04              -0.00
# 2018-08-31        967514.87    0.00              -0.00
# 2018-09-28        966698.79   -0.00              -0.00
# 2018-10-31        861069.23   -0.11              -0.11
# 2018-11-30        824817.71   -0.04              -0.15
# 2018-12-31        823121.63   -0.00              -0.15
# 2019-01-31        869634.50    0.06              -0.10
# 2019-02-28        850859.08   -0.02              -0.12
# 2019-03-29        859388.86    0.01              -0.11
# 2019-04-30        885320.91    0.03              -0.09
# ...

# %%
results["2018-01-31"]["globalResults"]
# Out:
#         Initial portfolio value Final portfolio value  Return        Cash  \
# Results             $967,640.95           $922,788.81  -4.64%  $38,220.10
#
#         Total capital
# Results   $961,008.91

# %% [markdown]
# ## <font color= #6B6B6B> 3.2 Passive Investment Strategy: In-Pandemic (28-02-2020 to 26-02-2021) </font>

# %%
results["2020-02-28"]["portfolioInfo"]
# Out:
#             Capital allocation  Cost per share (commission included)  \
# AMXL                 144600.00                                 14.55
# FEMSAUBD             118100.00                                153.54
# WALMEX               111600.00                                 53.59
# GFNORTEO             104300.00                                101.93
# GMEXICOB              59200.00                                 40.98
# CEMEXCPO              38300.00                                  6.35
# TLEVISACPO            37200.00                                 36.62
# GAPB                  32100.00                                203.19
# ELEKTRA               30900.00                               1319.98
# ASURB                 26200.00                                318.26
# KIMBERA               22800.00                                 33.83
# AC                    21000.00                                 97.97
# GFINBURO              19000.00                                 21.15
# ...

# %%
results["2020-02-28"]["portfolioPerformance"]
# Out:
#             Portfolio value  Return  Cumulative return
# Date
# 2020-02-28        986767.86    0.00               0.00
# 2020-03-31        825101.00   -0.16              -0.16
# 2020-04-30        874727.99    0.06              -0.11
# 2020-05-29        872312.95   -0.00              -0.12
# 2020-06-30        912025.72    0.05              -0.08
# 2020-07-31        900281.76   -0.01              -0.09
# 2020-08-31        897728.16   -0.00              -0.09
# 2020-09-30        912701.93    0.02              -0.08
# 2020-10-30        903080.00   -0.01              -0.08
# 2020-11-30       1029609.10    0.14               0.04
# 2020-12-31       1085964.72    0.05               0.10
# 2021-01-29       1058153.59   -0.03               0.07
# 2021-02-25       1093608.19    0.03               0.11

# %%
results["2020-02-28"]["globalResults"]
# Out:
#         Initial portfolio value Final portfolio value  Return        Cash  \
# Results             $986,767.86         $1,093,608.19  10.83%  $11,998.68
#
#          Total capital
# Results  $1,105,606.88

# %% [markdown]
# ## <font color= #6B6B6B> 3.3 Passive Investment Strategy: "Post"-Pandemic (31-03-2021 to 01-02-2022) </font>

# %%
results["2021-03-31"]["portfolioInfo"]
# Out:
#             Capital allocation  Cost per share (commission included)  \
# GMEXICOB             118300.00                                101.68
# AMXL                 114200.00                                 13.65
# WALMEX               112600.00                                 63.92
# FEMSAUBD              98800.00                                152.05
# GFNORTEO              97300.00                                110.05
# CEMEXCPO              75300.00                                 14.44
# TLEVISACPO            31700.00                                 36.18
# ELEKTRA               27700.00                               1376.00
# GAPB                  27000.00                                203.19
# ASURB                 25000.00                                355.63
# BIMBOA                20700.00                                 41.89
# ORBIA                 19000.00                                 52.62
# GRUMAB                17400.00                                237.79
# ...

# %%
results["2021-03-31"]["portfolioPerformance"]
# Out:
#             Portfolio value  Return  Cumulative return
# Date
# 2021-03-31        990140.34    0.00               0.00
# 2021-04-30       1011152.79    0.02               0.02
# 2021-05-31       1078013.88    0.07               0.09
# 2021-06-30       1064297.10   -0.01               0.07
# 2021-07-30       1076349.67    0.01               0.09
# 2021-08-31       1129777.21    0.05               0.14
# 2021-09-30       1089560.44   -0.04               0.10
# 2021-10-29       1079400.72   -0.01               0.09
# 2021-11-30       1054408.13   -0.02               0.06
# 2021-12-31       1131941.22    0.07               0.14
# 2022-01-31       1091392.47   -0.04               0.10

# %%
results["2021-03-31"]["globalResults"]
# Out:
#         Initial portfolio value Final portfolio value  Return        Cash  \
# Results             $990,140.34         $1,091,392.47  10.23%  $21,429.75
#
#          Total capital
# Results  $1,112,822.23

# %% [markdown]
# <br>

# %% [markdown]
# <br>

# %% [markdown]
# # <font color= #6B6B6B> <font size = 6> 6. References </font>

# %% [markdown]
# <hr style="border:0.02in solid gray"> </hr>

# %% [markdown]
# <br>
